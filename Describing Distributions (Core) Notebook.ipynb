# %% [markdown]
# # Describing Distributions (Core)
#
#
# In this assignment, you will be analyzing & visualizing several features in the Medical Dataset.
#
# The features to analyze:
# * VitD_levels
# * Doc_visits
# * TotalCharge

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %%
df = pd.read_csv('Data/Medical.csv')
df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %% [markdown]
# #### Explore the data of the features by displaying their value counts

# %%
df['VitD_levels'].value_counts()
# Out:
# 19.141466    1
# 18.180901    1
# 21.097365    1
# 18.670625    1
# 18.988771    1
#             ..
# 13.306814    1
# 16.019013    1
# 14.088522    1
# 15.801872    1
# 19.487658    1
# Name: VitD_levels, Length: 1000, dtype: int64

# %%
sns.histplot(data=df, x='VitD_levels', discrete=True, stat='density', kde = True);

# %%
col = 'VitD_levels'

feature = df[col]
mean = feature.mean()
median = feature.median()
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.set_title(f'{col}')
ax.legend();

# %%
df['Doc_visits'].value_counts()
# Out:
# 5    394
# 4    232
# 6    229
# 3     69
# 7     66
# 2      5
# 8      4
# 9      1
# Name: Doc_visits, dtype: int64

# %%
df['TotalCharge'].value_counts()
# Out:
# 3726.702860    1
# 3519.071379    1
# 2916.906301    1
# 3241.796541    1
# 2730.309350    1
#               ..
# 3283.523074    1
# 3701.824248    1
# 3680.545305    1
# 3496.001774    1
# 2830.020820    1
# Name: TotalCharge, Length: 1000, dtype: int64

# %% [markdown]
# ## Plot simple Histplots  so you can see General direction of each feature

# %%
sns.histplot(data=df, x='VitD_levels')
# Out:
# <AxesSubplot:xlabel='VitD_levels', ylabel='Count'>

# %%
sns.histplot(data=df, x='Doc_visits')
# Out:
# <AxesSubplot:xlabel='Doc_visits', ylabel='Count'>

# %%
sns.histplot(data=df, x='TotalCharge')
# Out:
# <AxesSubplot:xlabel='TotalCharge', ylabel='Count'>

# %% [markdown]
# ## Plot each Feature with the Mean represented as a red line and the Median represented as a Green Line Include additional lines for +1 and -1 Standard Deviations. Highlight the range between -1 and +1 Standard deviations.

# %%
col = 'Doc_visits'


feature = df[col]
mean = feature.mean()
median = feature.median()
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.set_title(f'{col}')
ax.legend();

# %%
col = 'VitD_levels'

feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %%
col = 'Doc_visits'

feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %%
col = 'TotalCharge'

feature = df[col]
mean = feature.mean()
median = feature.median()
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.set_title(f'{col}')
ax.legend();

# %%
col = 'TotalCharge'

feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# #### For Each Feature Answer the following questions:
# 1. Is it Discrete or Continuous?
# 2. Does it have a skew? If so, which direction (+/-)
# 3. What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)

# %% [markdown]
# ### VitD_levels
# 1. The Vitamin D levels feature is a Continuous feature
# 2. The Vitamin D has a Standard Normal Distribution
# 3. The Distribution of VitD_levels looks mesokurtic because it has a normal distribution.

# %% [markdown]
# ### Doc_vists
# 1. Doc_vists is a Discrete feature in this dataset although it can potentially be continous
# 2. The feature looks like it has a positive/normal distribution
# 3. mainly Mesokurtic because Mean and Median are on the same line

# %% [markdown]
# ### Total Charge
# 1. Total Charge is a continous feature
# 2. Total charge skews slightly  to the left but has standard normal distribution.
# 3. mesokurtic
